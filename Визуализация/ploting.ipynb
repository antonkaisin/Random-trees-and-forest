# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
students_perfomance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
students_perfomance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_perfomance.iloc[:,6].hist()
# Out:
# <AxesSubplot:>

# %%
students_perfomance.plot.scatter(x='math score', y = 'reading score')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='reading score'>

# %%
sns.set_theme()
ax = sns.lmplot(x='math score', y = 'reading score', hue='gender',data=students_perfomance, fit_reg=False) 
ax.set_xlabels('Math score')
ax.set_ylabels('Reading score')

# %%
df = pd.read_csv('income.csv')

# %%
df
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
df.income.plot()
# Out:
# <AxesSubplot:>

# %%
ds = pd.read_csv('dataset_209770_6.txt',sep = " ")

# %%
ds
# Out:
#               x            y
# 0   1410.700646   896.228948
# 1   1389.041011   908.652464
# 2    798.267599  1487.415565
# 3   1289.420969   102.119267
# 4    105.894960  1188.442532
# 5    791.311521  1497.437594
# 6     95.907243  1195.014916
# 7   1399.947154   914.987200
# 8   1292.820128    97.597148
# 9    807.922178  1509.194367
# 10   104.106204  1185.895407
# 11    91.216759  1209.412372
# 12   108.334294  1196.936637
# 13   805.827510  1505.351509
# 14  1294.011308   103.535804
# 15  1310.567631    98.762745
# 16  1408.899656   890.458708
# 17   802.991758  1493.356312
# 18  1287.077272   107.703299
# 19  1315.588767   102.044049
# 20  1407.486650   904.017405
# 21  1401.624714   897.554303
# 22   974.628292  1408.086744
# 23    93.233840  1207.985744
# 24  1001.029676  1399.850425
# 25  1004.146807  1401.535736
# 26    90.232999  1187.989410
# 27  1293.581282   107.863397
# 28    99.981273  1200.612616
# 29   994.518896  1400.542508
# 30  1009.698333  1405.075694
# ...

# %%
sns.lmplot(x='x', y = 'y',data=ds, fit_reg=False) 
#sns.scatterplot(df.iloc[:, 0], df.iloc[:, 1])

# %%
h_map = pd.read_csv('genome_matrix.csv', sep = ",", index_col=0)

# %%
h_map
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g=sns.heatmap(h_map,cmap="viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
dota = pd.read_csv('dota_hero_stats.csv', sep = ",", index_col=0)

# %%
dota
# Out:
#     attack_type   id  legs  localized_name                          name  \
# 0         Melee    1     2       Anti-Mage        npc_dota_hero_antimage
# 1         Melee    2     2             Axe             npc_dota_hero_axe
# 2        Ranged    3     4            Bane            npc_dota_hero_bane
# 3         Melee    4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4        Ranged    5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
# ..          ...  ...   ...             ...                           ...
# 112       Melee  114     2     Monkey King     npc_dota_hero_monkey_king
# 113      Ranged  119     2     Dark Willow     npc_dota_hero_dark_willow
# 114       Melee  120     2       Pangolier       npc_dota_hero_pangolier
# 115      Ranged  121     2      Grimstroke      npc_dota_hero_grimstroke
# 116       Melee  129     2            Mars            npc_dota_hero_mars
#
#     primary_attr                                              roles
# ...

# %%
(dota['roles'].str.count(',')+1).mode()
# Out:
# 0    4
# dtype: int64

# %%
iris = pd.read_csv('iris.csv', index_col=0)

# %%
iris
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
sns.kdeplot(data=iris, x="sepal length")
# Out:
# <AxesSubplot:xlabel='sepal length', ylabel='Density'>

# %%
sns.distplot(iris['petal length'])
# Out:
# c:\Users\anton\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal length', ylabel='Density'>

# %%
iris.describe()
# Out:
#        sepal length  sepal width  petal length  petal width     species
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667    1.000000
# std        0.828066     0.433594      1.764420     0.763161    0.819232
# min        4.300000     2.000000      1.000000     0.100000    0.000000
# 25%        5.100000     2.800000      1.600000     0.300000    0.000000
# 50%        5.800000     3.000000      4.350000     1.300000    1.000000
# 75%        6.400000     3.300000      5.100000     1.800000    2.000000
# max        7.900000     4.400000      6.900000     2.500000    2.000000

# %%
sns.violinplot(y=iris['petal length'], data=iris)
# Out:
# <AxesSubplot:ylabel='petal length'>

# %%
sns.pairplot(data=iris, hue='species')

# %%
iris.corr()
# Out:
#               sepal length  sepal width  petal length  petal width   species
# sepal length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000
